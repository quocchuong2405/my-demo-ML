# %%
import pandas as pd 
import numpy as np 
from sklearn.datasets import make_swiss_roll
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from sklearn.manifold import LocallyLinearEmbedding

# %%
X, t = make_swiss_roll(n_samples=10000, noise=0.2, random_state=41)

# %%
X
# Out:
# array([[  4.98526052,  20.06364829,   5.22848474],
#        [  1.8002197 ,   8.99419163,  -4.29184948],
#        [  1.19473534,   8.63204206, -11.29776882],
#        ...,
#        [  6.12894424,   7.22016384,   2.53967306],
#        [ 11.24020041,  17.17817153,   6.95394839],
#        [ -7.29539068,  14.10671613,  -7.29939381]])

# %%
t.shape
# Out:
# (10000,)

# %%
fig = plt.figure(figsize=(16,13))
ax = fig.add_subplot(2,2,1,projection='3d')
ax.scatter(X[:,0], X[:,1], X[:,2], c=t, cmap= plt.cm.hsv)
ax.view_init(10, -66)
ax.set_xlabel("$x_1$", fontsize = 18)
ax.set_ylabel("$x_2$", fontsize = 18)
ax.set_zlabel("$x_3$", fontsize = 18)
ax.set_title("Swiss Roll Data", fontsize = 22)
# Out:
# Text(0.5, 0.92, 'Swiss Roll Data')

# %%
lle = LocallyLinearEmbedding(n_components=2, n_neighbors=10, random_state=42)
X_reduced = lle.fit_transform(X)

# %%
X_reduced
# Out:
# array([[ 0.01156655, -0.01647727],
#        [ 0.01114085,  0.01762954],
#        [-0.00572139, -0.00476841],
#        ...,
#        [ 0.00940545,  0.00844906],
#        [-0.01523926,  0.00504385],
#        [-0.00084343, -0.010249  ]])

# %%
plt.title("Swiss Roll after using LLE", fontsize = 22)
plt.scatter(X_reduced[:,0], X_reduced[:,1], c=t, cmap=plt.cm.hsv)
plt.xlabel("$z_1$", fontsize = 18)
plt.ylabel("$z_2$", fontsize = 18)
plt.grid(True)
